# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalen-Hall/jalen/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Jalen Hall")
print("o----")
print('||||')
print('*'*10)
# Out:
# Jalen Hall
# o----
# ||||
# **********
