# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalen-Hall/jalen/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mylist = [ 1, 2, 3, 4]

print("length of the list is:\n" + str(len(mylist)))
# Out:
# length of the list is:
# 4
